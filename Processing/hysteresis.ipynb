# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# %%
final_df= pd.read_csv('./Corrected Data/baseline.csv')
cycle_1 = pd.read_csv('./Corrected Data/cycle_1.csv')
cycle_2 = pd.read_csv('./Corrected Data/cycle_2.csv')
cycle_3 = pd.read_csv('./Corrected Data/cycle_3.csv')
cycle_4 = pd.read_csv('./Corrected Data/cycle_4.csv')
cycle_5 = pd.read_csv('./Corrected Data/cycle_5.csv')
cycle_6 = pd.read_csv('./Corrected Data/cycle_6.csv')
cycle_7 = pd.read_csv('./Corrected Data/cycle_7.csv')
cycle_8 = pd.read_csv('./Corrected Data/cycle_8.csv')
cycle_9 = pd.read_csv('./Corrected Data/cycle_9.csv')
cycle_10 = pd.read_csv('./Corrected Data/cycle_10.csv')

# %%
final_df['Timestamp'] = pd.to_datetime(final_df['Timestamp'])
final_df['period'] = (final_df['Timestamp'] - final_df['Timestamp'].iloc[0]).dt.total_seconds()
cycle_1['Timestamp'] = pd.to_datetime(cycle_1['Timestamp'])
cycle_1['period'] = (cycle_1['Timestamp'] - cycle_1['Timestamp'].iloc[0]).dt.total_seconds()
cycle_2['Timestamp'] = pd.to_datetime(cycle_2['Timestamp'])
cycle_2['period'] = (cycle_2['Timestamp'] - cycle_2['Timestamp'].iloc[0]).dt.total_seconds()
cycle_3['Timestamp'] = pd.to_datetime(cycle_3['Timestamp'])
cycle_3['period'] = (cycle_3['Timestamp'] - cycle_3['Timestamp'].iloc[0]).dt.total_seconds()
cycle_4['Timestamp'] = pd.to_datetime(cycle_4['Timestamp'])
cycle_4['period'] = (cycle_4['Timestamp'] - cycle_4['Timestamp'].iloc[0]).dt.total_seconds()
cycle_5['Timestamp'] = pd.to_datetime(cycle_5['Timestamp'])
cycle_5['period'] = (cycle_5['Timestamp'] - cycle_5['Timestamp'].iloc[0]).dt.total_seconds()
cycle_6['Timestamp'] = pd.to_datetime(cycle_6['Timestamp'])
cycle_6['period'] = (cycle_6['Timestamp'] - cycle_6['Timestamp'].iloc[0]).dt.total_seconds()
cycle_7['Timestamp'] = pd.to_datetime(cycle_7['Timestamp'])
cycle_7['period'] = (cycle_7['Timestamp'] - cycle_7['Timestamp'].iloc[0]).dt.total_seconds()
cycle_8['Timestamp'] = pd.to_datetime(cycle_8['Timestamp'])
cycle_8['period'] = (cycle_8['Timestamp'] - cycle_8['Timestamp'].iloc[0]).dt.total_seconds()
cycle_9['Timestamp'] = pd.to_datetime(cycle_9['Timestamp'])
cycle_9['period'] = (cycle_9['Timestamp'] - cycle_9['Timestamp'].iloc[0]).dt.total_seconds()
cycle_10['Timestamp'] = pd.to_datetime(cycle_10['Timestamp'])
cycle_10['period'] = (cycle_10['Timestamp'] - cycle_10['Timestamp'].iloc[0]).dt.total_seconds()

# %%
# Step 1: Clean Data
df = final_df.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Baseline')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_1.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 1')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_2.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df[df['Ch3 TC Temp (Chart) (°C)'] >= 595]
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 2')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_3.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 3')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_4.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df[df['Ch3 TC Temp (Chart) (°C)'] >= 595]
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 4')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_5.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df[df['Ch3 TC Temp (Chart) (°C)'] >= 595]
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 5')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_6.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df[df['Ch3 TC Temp (Chart) (°C)'] >= 595]
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 6')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_7.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 7')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_8.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 8')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Step 1: Clean Data
df = cycle_9.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 9')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df = cycle_10.dropna(subset=['Ch3 TC Temp (Chart) (°C)', 'Ch3 TC EMF (mV)']).copy()
df = df.sort_values('period')

# Step 2: Compute derivative of temperature to detect direction
df['dT'] = df['Ch3 TC Temp (Chart) (°C)'].diff()

# Heating phase = positive temperature change
heating = df[df['dT'] > 0]
cooling = df[df['dT'] < 0]

# Step 3: Plot
plt.figure(figsize=(10, 6))

plt.plot(heating['Ch3 TC Temp (Chart) (°C)'], heating['Ch3 TC EMF (mV)'],
         label='Heating', color='red', linewidth=2)

plt.plot(cooling['Ch3 TC Temp (Chart) (°C)'], cooling['Ch3 TC EMF (mV)'],
         label='Cooling', color='blue', linewidth=2)

plt.xlabel('Temperature (°C)')
plt.ylabel('EMF (mV)')
plt.title('Hysteresis Curve - Channel 3 - Cycle 10')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
